# %% [markdown]
# ##### MAIN OVERVIEW:
# ##### Written 2023/06 by Caroline Goodman and refined by Christina Lebonville 2023/07.
# ##### Last updated: 2023/08/10 CL
#
# ##### REQUIRES KERNEL "firstEnv"
# ##### For Determining Real Bouts from Fiber Photometry Videos using DeepEthogram - Integrates DEG Predictions and FP Output
#     For each workbook:
#         - find file containing labels that correspond to workbook
#         - determine % of consumatory frames according to DEG
#         - update dataframe to include % consumatory frames
#         - save updated dataframe to updated_workbooks folder

# %% [markdown]
# ##### Import necessary packages.

# %%
import pandas as pd
import os

# %% [markdown]
# ##### get_consumatory_percentage(workbook, labels):
#     - takes each bout period and converts it to DEG frames. Then computes percent of DEG labels during this period that are labeled consumatory
# ##### get_corresponding_labels_file(file_path):
#     - finds the file containing the DEG predictions that correspond to the TDT Fiber data
#     - For example:
#         - 20221202CL20A6B5quinineresultsB.xlsx corresponds to --> 20221201CL20A6B5quinine_Cam1B_predictions.xlsx
# ##### generate_new_file(labels_path, workbook_df):
#     - imports the predictions into a dataframe based on frame numbers and runs the update_workbook function
# ##### update_workbook(workbook_df, percentages, file_path):
#     - adds the column to the TDT Fiber data xlsx to report % consumatory within bout
#     - saves updated workbook to updated_workbooks folder

# %%
def get_consumatory_percentage(workbook, labels):
    bout_percentages = []
    # for each bout
    # get start and end frame
    for start, duration in zip(workbook[workbook.columns[0]], workbook[workbook.columns[1]]):
        end = start+duration
        start = round((start+15)*10)
        end = round((end+15)*10)
        consum = 0
        total = 0
        error = []
        #print(start, end)
        # for each frame in the bout
        for frame_number in range(start, end+1):
            #print(frame_number)
            if frame_number in labels[labels.columns[0]]:
                if labels.loc[frame_number, 'C'] == 1:
                    #print('C')
                    consum += 1
                    total += 1
                else:
                    #print('NC')
                    total += 1
        if total == 0:
            print("WARNING: Some frames in workbook were not found in the predictions file")
            percent_consumatory = "error" 
            bout_percentages.append(percent_consumatory) 
        else: 
            #print(total)
            percent_consumatory = consum/total
            #print(consum, "/", total, "=", percent_consumatory)
            bout_percentages.append(percent_consumatory)  
    return bout_percentages
           
def get_corresponding_labels_file(file_path):
    cam = file_path[-6]
    file_name_chunk = file_path[:-13]
    print("Looking for labels...")
    return f"Lebonville_{file_name_chunk}_Cam1{cam}_predictions.csv"

def update_workbook(workbook_df, percentages, file_path):
    ## Feature Predictions
    #output_path = os.path.join(r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\updated_workbooks\feature_predictions", file_path)
    ##Sequence Predictions
    #output_path = os.path.join(r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\updated_workbooks\sequence_predictions", file_path)
    output_path = os.path.join(r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks", file_path)
    
    # Add column denoting % Consumatory
    workbook_df['% of C'] = percentages
    
    # Create new Excel file with updated 'C or NC' column; saved to the updated_workbooks folder
    workbook_df.to_excel(output_path, index=False, engine='xlsxwriter')
    print("-----------> updated workbook exported to:", output_path)

def generate_new_file(labels_path, workbook_df, file):
    
    #create data frame for labels file
    labels_df = pd.read_csv(labels_path)
    
    # get frame ranges
    consumatory_percentages = get_consumatory_percentage(workbook_df, labels_df)
    
    # update and export the excel with % consumatory
    update_workbook(workbook_df, consumatory_percentages, file)

def main():
    
    #workbooks_directory = r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model" #This is the folder containing FP output files
    workbooks_directory = r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\CL8_Data"
    
    ##Feature Predictions
    #labels_directory = r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\PerformanceCheck\feature_predictions" #This is the DEG prediction folder (.csv)
    ##Sequence Predictions
    #labels_directory = r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\PerformanceCheck\sequence_predictions" #This is the DEG prediction folder (.csv)
    labels_directory = r"\\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Gen4-5_Predictions"
    
    for file in os.listdir(workbooks_directory):
        # add individual file to file path
        file_path = os.path.join(workbooks_directory, file)
        print(file)
        # create data frame for particular file path
        workbook_df = pd.read_excel(file_path, 'Sheet4')
        
        # if bouts were found
        if 'ABoutStarts' in workbook_df.columns or 'BBoutStarts' in workbook_df.columns:
            
            # get labels file for particular file path
            os.chdir(labels_directory)
            labels_path = get_corresponding_labels_file(file)
            
            # continue only if a labels file is found in the directory
            if os.path.isfile(labels_path):
                generate_new_file(labels_path, workbook_df, file)
            else:
                print("No Labels File Found")

# %%
main()
# Out:
# 20201026CL8A1B8resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201026CL8A1B8resultsA.xlsx
# 20201026CL8A1B8resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201026CL8A1B8resultsB.xlsx
# 20201028CL8A4B10resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201028CL8A4B10resultsA.xlsx
# 20201028CL8A4B10resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201028CL8A4B10resultsB.xlsx
# 20201029CL8A13B5resultsA.xlsx
# Looking for labels...
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201029CL8A13B5resultsA.xlsx
# 20201029CL8A13B5resultsB.xlsx
# Looking for labels...
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201029CL8A13B5resultsB.xlsx
# 20201030CL8A6B8resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201030CL8A6B8resultsA.xlsx
# 20201030CL8A6B8resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201030CL8A6B8resultsB.xlsx
# 20201102CL8A1B8resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201102CL8A1B8resultsA.xlsx
# 20201102CL8A1B8resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201102CL8A1B8resultsB.xlsx
# 20201103CL8A9B3resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201103CL8A9B3resultsA.xlsx
# 20201103CL8A9B3resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201103CL8A9B3resultsB.xlsx
# 20201104CL8A4B10resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201104CL8A4B10resultsA.xlsx
# 20201104CL8A4B10resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201104CL8A4B10resultsB.xlsx
# 20201105CL8A13B5resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201105CL8A13B5resultsA.xlsx
# 20201105CL8A13B5resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201105CL8A13B5resultsB.xlsx
# 20201106CL8A6B10resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201106CL8A6B10resultsA.xlsx
# 20201106CL8A6B10resultsB.xlsx
# 20201109CL8A1B8resultsA.xlsx
# 20201109CL8A1B8resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201109CL8A1B8resultsB.xlsx
# 20201110CL8A9B3resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201110CL8A9B3resultsA.xlsx
# 20201110CL8A9B3resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201110CL8A9B3resultsB.xlsx
# 20201111CL8A4B10resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201111CL8A4B10resultsA.xlsx
# 20201111CL8A4B10resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201111CL8A4B10resultsB.xlsx
# 20201112CL8A13B5resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201112CL8A13B5resultsA.xlsx
# 20201112CL8A13B5resultsB.xlsx
# 20201113CL8A6B5resultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201113CL8A6B5resultsA.xlsx
# 20201113CL8A6B5resultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201113CL8A6B5resultsB.xlsx
# 20201116CL8A1B8WaterresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201116CL8A1B8WaterresultsA.xlsx
# 20201116CL8A1B8WaterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201116CL8A1B8WaterresultsB.xlsx
# 20201117CL8A9B3WaterresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201117CL8A9B3WaterresultsA.xlsx
# 20201117CL8A9B3WaterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201117CL8A9B3WaterresultsB.xlsx
# 20201118CL8A4B10WaterresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20201118CL8A4B10WaterresultsA.xlsx
# 20201118CL8A4B10WaterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20
aterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220525CL8A17B23WaterresultsB.xlsx
# 20220526CL8A18B20WaterresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220526CL8A18B20WaterresultsA.xlsx
# 20220526CL8A18B20WaterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220526CL8A18B20WaterresultsB.xlsx
# 20220527CL8A18B21WaterresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220527CL8A18B21WaterresultsA.xlsx
# 20220527CL8A18B21WaterresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220527CL8A18B21WaterresultsB.xlsx
# 20220530CL8A14B21SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220530CL8A14B21SucroseresultsA.xlsx
# 20220530CL8A14B21SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220530CL8A14B21SucroseresultsB.xlsx
# 20220531CL8A22B15SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220531CL8A22B15SucroseresultsA.xlsx
# 20220531CL8A22B15SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220531CL8A22B15SucroseresultsB.xlsx
# 20220601CL8A17B23SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220601CL8A17B23SucroseresultsA.xlsx
# 20220601CL8A17B23SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220601CL8A17B23SucroseresultsB.xlsx
# 20220602CL8A18B20SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220602CL8A18B20SucroseresultsA.xlsx
# 20220602CL8A18B20SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220602CL8A18B20SucroseresultsB.xlsx
# 20220603CL8A18B23SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220603CL8A18B23SucroseresultsA.xlsx
# 20220603CL8A18B23SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220603CL8A18B23SucroseresultsB.xlsx
# 20220606CL8A14B21SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220606CL8A14B21SucroseresultsA.xlsx
# 20220606CL8A14B21SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220606CL8A14B21SucroseresultsB.xlsx
# 20220607CL8A22B15SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220607CL8A22B15SucroseresultsA.xlsx
# 20220607CL8A22B15SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220607CL8A22B15SucroseresultsB.xlsx
# 20220608CL8A17B23SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220608CL8A17B23SucroseresultsA.xlsx
# 20220608CL8A17B23SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220608CL8A17B23SucroseresultsB.xlsx
# 20220609CL8A18B20SucroseresultsA.xlsx
# 20220609CL8A18B20SucroseresultsB.xlsx
# Looking for labels...
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# WARNING: Some frames in workbook were not found in the predictions file
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220609CL8A18B20SucroseresultsB.xlsx
# 20220610CL8A18B15SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220610CL8A18B15SucroseresultsA.xlsx
# 20220610CL8A18B15SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220610CL8A18B15SucroseresultsB.xlsx
# 20220613CL8A14B21SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220613CL8A14B21SucroseresultsA.xlsx
# 20220613CL8A14B21SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220613CL8A14B21SucroseresultsB.xlsx
# 20220614CL8A22B15SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220614CL8A22B15SucroseresultsA.xlsx
# 20220614CL8A22B15SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220614CL8A22B15SucroseresultsB.xlsx
# 20220615CL8A17B23SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220615CL8A17B23SucroseresultsA.xlsx
# 20220615CL8A17B23SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220615CL8A17B23SucroseresultsB.xlsx
# 20220616CL8A18B20SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220616CL8A18B20SucroseresultsA.xlsx
# 20220616CL8A18B20SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220616CL8A18B20SucroseresultsB.xlsx
# 20220617CL8A14B15SucroseresultsA.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220617CL8A14B15SucroseresultsA.xlsx
# 20220617CL8A14B15SucroseresultsB.xlsx
# Looking for labels...
# -----------> updated workbook exported to: \\mulhollnas.thurmond-gazes.musc.edu\mulhollnas\Christina_Lebonville\TrueBout_2023_CL8_CL20_DEG_Model\Updated_CL8_Workbooks\20220617CL8A14B15SucroseresultsB.xlsx

# %% [markdown]
# ##### CHANGELOG ######
# ##### 2023.08.10 - CL added code to deal with errors where frames were not found in the prediction files - meaning the videos were shorter than the fiber data for some reason (likely crashing). These bouts will now show "error" in their %C column and a warning will be printed.
